# %%
import pandas as pd

T=pd.read_csv(r'C:\Users\julia\Documents\python36\datasource\data\skincancer.txt', delim_whitespace=True)

T.head()
# Out:
#         State   Lat  Mort  Ocean   Long
# 0     Alabama  33.0   219      1   87.0
# 1     Arizona  34.5   160      0  112.0
# 2    Arkansas  35.0   170      0   92.5
# 3  California  37.5   182      1  119.5
# 4    Colorado  39.0   149      0  105.5

# %%
import seaborn as sn
import pylab as pl
from scipy.stats import linregress

# %%
sn.regplot(x="Lat",y="Mort",data=T,ci=None)
# Out:
# <AxesSubplot: xlabel='Lat', ylabel='Mort'>

# %%
R = linregress(T['Lat'], T['Mort'])
a,b,r=R[0],R[1],R[2]
print(a,b,r)
# Out:
# -5.977635744411936 389.1893510306196 -0.8245177937800733

# %%
sn.lmplot(x="Lat",y="Mort",data=T,
         hue='Ocean',ci=None,
         markers=["o","x"])
